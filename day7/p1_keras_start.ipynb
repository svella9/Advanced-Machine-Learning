# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from sklearn import datasets
# Out:
# C:\Users\KNatarajan\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
digits = datasets.load_digits()
X, y = digits.data[0:1777], digits.target[:-20]

# %%
model = Sequential()
model.add(Dense(units=12, activation='relu', input_shape = (64,)))
model.add(Dense(9, activation = 'relu'))
model.add(Dense(9, activation = 'relu'))
model.add(Dense(units=10, activation = 'softmax'))
model.compile(loss = 'sparse_categorical_crossentropy', optimizer = 'sgd', metrics=['accuracy'])
model.fit(X, y, epochs = 100)
# Out:
# Epoch 1/100
# 1777/1777 [==============================] - 1s 511us/step - loss: 2.2848 - acc: 0.1880
# Epoch 2/100
# 1777/1777 [==============================] - 0s 108us/step - loss: 2.0137 - acc: 0.3061
# Epoch 3/100
# 1777/1777 [==============================] - 0s 105us/step - loss: 1.8416 - acc: 0.3669
# Epoch 4/100
# 1777/1777 [==============================] - 0s 108us/step - loss: 1.7383 - acc: 0.3815
# Epoch 5/100
# 1777/1777 [==============================] - 0s 90us/step - loss: 1.6699 - acc: 0.4041
# Epoch 6/100
# 1777/1777 [==============================] - 0s 83us/step - loss: 1.6110 - acc: 0.4153
# Epoch 7/100
# 1777/1777 [==============================] - 0s 86us/step - loss: 1.5763 - acc: 0.4204
# Epoch 8/100
# 1777/1777 [==============================] - 0s 88us/step - loss: 1.5307 - acc: 0.4226
# Epoch 9/100
# 1777/1777 [==============================] - 0s 79us/step - loss: 1.4963 - acc: 0.4395
# Epoch 10/100
# ...

# %%
score = model.evaluate(digits.data[0:1797], digits.target[0:1797], verbose = 1)
print(score)
# Out:
# 1797/1797 [==============================] - 0s 120us/step
# [0.04267836816849381, 0.9905397885364496]

# %%
pred_arr = model.predict(digits.data[0:20])
for i in range(20):
    print("Actual target", digits.target[i])
    print('Prediction', np.argmax(pred_arr[i]))
    print('==============================================')
# Out:
# Actual target 0
# Prediction 0
# ...
# Actual target 1
# Prediction 1
# ...
# Actual target 2
# Prediction 2
# ...
# Actual target 3
# Prediction 3
# ...
# Actual target 4
# Prediction 4
# ...
# Actual target 5
# Prediction 9
# ...
# Actual target 6
# Prediction 6
# ...
# Actual target 7
# Prediction 7
# ...
# Actual target 8
# Prediction 8
# ...
# Actual target 9
# Prediction 9
# ...
# Actual target 0
# Prediction 0
# ...
# Actual target 1
# Prediction 1
# ...
# Actual target 2
# Prediction 2
# ...
# Actual target 3
# Prediction 3
# ...
# Actual target 4
# Prediction 4
# ...
# Actual target 5
# Prediction 5
# ...
# Actual target 6
# Prediction 6
# ...
# Actual target 7
# Prediction 7
# ...
# Actual target 8
# Prediction 8
# ...
# Actual target 9
# Prediction 9
# ...
